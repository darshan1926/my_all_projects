# %%
import pandas as pd
import matplotlib.pyplot as mpl
import seaborn as sb
import numpy as np
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Lenovo'

# %%
os.chdir('C:\\Users\\Lenovo\\Downloads')

# %%
df=pd.read_csv("car data.csv")

# %%
df.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
for feature in df:
    data=df.copy()
    data[feature].hist(bins=25)
    mpl.xlabel(feature)
    mpl.ylabel("Count")
    mpl.title(feature)
    mpl.show()

# %%
#df.drop(['Owner'],axis=1,inplace=True)

# %%
df.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %%
x=df.iloc[:,:5]
print(x.head())
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven
# 0     ritz  2014           3.35           5.59       27000
# 1      sx4  2013           4.75           9.54       43000
# 2     ciaz  2017           7.25           9.85        6900
# 3  wagon r  2011           2.85           4.15        5200
# 4    swift  2014           4.60           6.87       42450

# %%
print(df['Seller_Type'].unique())
print(df['Transmission'].unique())
print(df['Owner'].unique())
print(df['Car_Name'].unique())
print(df['Year'].unique())
print(df['Fuel_Type'].unique())
# Out:
# ['Dealer' 'Individual']
# ['Manual' 'Automatic']
# [0 1 3]
# ['ritz' 'sx4' 'ciaz' 'wagon r' 'swift' 'vitara brezza' 's cross'
#  'alto 800' 'ertiga' 'dzire' 'alto k10' 'ignis' '800' 'baleno' 'omni'
#  'fortuner' 'innova' 'corolla altis' 'etios cross' 'etios g' 'etios liva'
#  'corolla' 'etios gd' 'camry' 'land cruiser' 'Royal Enfield Thunder 500'
#  'UM Renegade Mojave' 'KTM RC200' 'Bajaj Dominar 400'
#  'Royal Enfield Classic 350' 'KTM RC390' 'Hyosung GT250R'
#  'Royal Enfield Thunder 350' 'KTM 390 Duke ' 'Mahindra Mojo XT300'
#  'Bajaj Pulsar RS200' 'Royal Enfield Bullet 350'
#  'Royal Enfield Classic 500' 'Bajaj Avenger 220' 'Bajaj Avenger 150'
#  'Honda CB Hornet 160R' 'Yamaha FZ S V 2.0' 'Yamaha FZ 16'
#  'TVS Apache RTR 160' 'Bajaj Pulsar 150' 'Honda CBR 150' 'Hero Extreme'
#  'Bajaj Avenger 220 dtsi' 'Bajaj Avenger 150 street' 'Yamaha FZ  v 2.0'
#  'Bajaj Pulsar  NS 200' 'Bajaj Pulsar 220 F' 'TVS Apache RTR 180'
#  'Hero Passion X pro' 'Bajaj Pulsar NS 200' 'Yamaha Fazer '
# ...

# %%
df.isnull().sum()
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Kms_Driven       0
# Fuel_Type        0
# Seller_Type      0
# Transmission     0
# Owner            0
# dtype: int64

# %%
df.describe()
# Out:
#               Year  Selling_Price  Present_Price     Kms_Driven       Owner
# count   301.000000     301.000000     301.000000     301.000000  301.000000
# mean   2013.627907       4.661296       7.628472   36947.205980    0.043189
# std       2.891554       5.082812       8.644115   38886.883882    0.247915
# min    2003.000000       0.100000       0.320000     500.000000    0.000000
# 25%    2012.000000       0.900000       1.200000   15000.000000    0.000000
# 50%    2014.000000       3.600000       6.400000   32000.000000    0.000000
# 75%    2016.000000       6.000000       9.900000   48767.000000    0.000000
# max    2018.000000      35.000000      92.600000  500000.000000    3.000000

# %%
df.columns
# Out:
# Index(['Car_Name', 'Year', 'Selling_Price', 'Present_Price', 'Kms_Driven',
#        'Fuel_Type', 'Seller_Type', 'Transmission', 'Owner'],
#       dtype='object')

# %%
f_df=df[['Year','Selling_Price','Present_Price','Kms_Driven','Fuel_Type','Seller_Type','Transmission','Owner']]

# %%
f_df.head()
# Out:
#    Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0  2014           3.35           5.59       27000    Petrol      Dealer
# 1  2013           4.75           9.54       43000    Diesel      Dealer
# 2  2017           7.25           9.85        6900    Petrol      Dealer
# 3  2011           2.85           4.15        5200    Petrol      Dealer
# 4  2014           4.60           6.87       42450    Diesel      Dealer
#
#   Transmission  Owner
# 0       Manual      0
# 1       Manual      0
# 2       Manual      0
# 3       Manual      0
# 4       Manual      0

# %%
f_df['no_year']=2022-f_df['Year']

# %%
f_df.head()
# Out:
#    Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0  2014           3.35           5.59       27000    Petrol      Dealer
# 1  2013           4.75           9.54       43000    Diesel      Dealer
# 2  2017           7.25           9.85        6900    Petrol      Dealer
# 3  2011           2.85           4.15        5200    Petrol      Dealer
# 4  2014           4.60           6.87       42450    Diesel      Dealer
#
#   Transmission  Owner  no_year
# 0       Manual      0        8
# 1       Manual      0        9
# 2       Manual      0        5
# 3       Manual      0       11
# 4       Manual      0        8

# %%
f_df.drop(['Year'],axis=1,inplace=True)

# %%
f_df.head()
# Out:
#    Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0           3.35           5.59       27000    Petrol      Dealer
# 1           4.75           9.54       43000    Diesel      Dealer
# 2           7.25           9.85        6900    Petrol      Dealer
# 3           2.85           4.15        5200    Petrol      Dealer
# 4           4.60           6.87       42450    Diesel      Dealer
#
#   Transmission  Owner  no_year
# 0       Manual      0        8
# 1       Manual      0        9
# 2       Manual      0        5
# 3       Manual      0       11
# 4       Manual      0        8

# %%
f_df=pd.get_dummies(f_df,drop_first=True)

# %%
f_df.head()
# Out:
#    Selling_Price  Present_Price  Kms_Driven  Owner  no_year  Fuel_Type_Diesel  \
# 0           3.35           5.59       27000      0        8                 0
# 1           4.75           9.54       43000      0        9                 1
# 2           7.25           9.85        6900      0        5                 0
# 3           2.85           4.15        5200      0       11                 0
# 4           4.60           6.87       42450      0        8                 1
#
#    Fuel_Type_Petrol  Seller_Type_Individual  Transmission_Manual
# 0                 1                       0                    1
# 1                 0                       0                    1
# 2                 1                       0                    1
# 3                 1                       0                    1
# 4                 0                       0                    1

# %%
f_df.corr()
# Out:
#                         Selling_Price  Present_Price  Kms_Driven     Owner  \
# Selling_Price                1.000000       0.878983    0.029187 -0.088344
# Present_Price                0.878983       1.000000    0.203647  0.008057
# Kms_Driven                   0.029187       0.203647    1.000000  0.089216
# Owner                       -0.088344       0.008057    0.089216  1.000000
# no_year                     -0.236141       0.047584    0.524342  0.182104
# Fuel_Type_Diesel             0.552339       0.473306    0.172515 -0.053469
# Fuel_Type_Petrol            -0.540571      -0.465244   -0.172874  0.055687
# Seller_Type_Individual      -0.550724      -0.512030   -0.101419  0.124269
# Transmission_Manual         -0.367128      -0.348715   -0.162510 -0.050316
#
#                          no_year  Fuel_Type_Diesel  Fuel_Type_Petrol  \
# Selling_Price          -0.236141          0.552339         -0.540571
# Present_Price           0.047584          0.473306         -0.465244
# ...

# %%
sb.pairplot(f_df)

# %%
corelation=f_df.corr()
#top_corr=corrmat.index
#plt.figure(figsize=(20,20))
g=sb.heatmap(f_df.corr(),annot=True,cmap="RdYlGn")

# %%
f_df.columns
# Out:
# Index(['Selling_Price', 'Present_Price', 'Kms_Driven', 'Owner', 'no_year',
#        'Fuel_Type_Diesel', 'Fuel_Type_Petrol', 'Seller_Type_Individual',
#        'Transmission_Manual'],
#       dtype='object')

# %%
categorical_col=[cname for cname in f_df.columns if f_df[cname].dtypes=='object']
numerical_col=[cname for cname in f_df.columns if f_df[cname].dtypes!='object']
print(categorical_col)
print(numerical_col)
# Out:
# []
# ['Selling_Price', 'Present_Price', 'Kms_Driven', 'Owner', 'no_year', 'Fuel_Type_Diesel', 'Fuel_Type_Petrol', 'Seller_Type_Individual', 'Transmission_Manual']

# %%
sb.countplot(x='Fuel_Type',data=df)
#mpl.xlable('Fuel_Type')
mpl.title('Distribution fuel type')
# Out:
# Text(0.5, 1.0, 'Distribution fuel type')

# %%
f_df['Selling_Price'].plot.box()
# Out:
# <AxesSubplot:>

# %%
f_df['Selling_Price'].plot.hist(bins=20,title='Selling price of car')
# Out:
# <AxesSubplot:title={'center':'Selling price of car'}, ylabel='Frequency'>

# %%
f_df.plot.scatter(x='Kms_Driven',y='Selling_Price',color='blue',title='kilometer and selling price Relationship')
# Out:
# <AxesSubplot:title={'center':'kilometer and selling price Relationship'}, xlabel='Kms_Driven', ylabel='Selling_Price'>

# %%
y=f_df.iloc[:,0]

# %%
x=f_df.iloc[:,1:]

# %%
y.head()
# Out:
# 0    3.35
# 1    4.75
# 2    7.25
# 3    2.85
# 4    4.60
# Name: Selling_Price, dtype: float64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=42)

# %%
from sklearn.linear_model import LinearRegression
LR=LinearRegression()
LR.fit(x_train,y_train)
y_pred=LR.predict(x_test)

# %%
from sklearn.metrics import mean_absolute_percentage_error
accuracy = 100 - np.mean(mean_absolute_percentage_error(y_test,y_pred))
print('Accuracy:', round(accuracy, 2), '%.')
# Out:
# Accuracy: 98.98 %.

# %%
from sklearn.metrics import mean_squared_error as mse
error=mse(y_test,y_pred)
print(error)
# Out:
# 3.378564707950634

# %%
from sklearn import metrics
print('Mean Absolute Error : ',metrics.mean_absolute_error(y_test,y_pred))
print('Mean Squared Error : ',metrics.mean_squared_error(y_test,y_pred))
print('Root Mean Squared Error : ',np.sqrt(metrics.mean_squared_error(y_test,y_pred)))
# Out:
# Mean Absolute Error :  1.2283245143225188
# Mean Squared Error :  3.378564707950634
# Root Mean Squared Error :  1.8380872416592837

# %%
import statsmodels.api as sm
# Add a constant to get an intercept
x_train_sm = sm.add_constant(x_train)

# Fit the resgression line using 'OLS'
lr = sm.OLS(y_train, x_train_sm).fit()

# %%
# Print the parameters, i.e. the intercept and the slope of the regression line fitted
lr.params
# Out:
# const                     5.467979
# Present_Price             0.424013
# Kms_Driven               -0.000005
# Owner                    -1.011350
# no_year                  -0.366738
# Fuel_Type_Diesel          2.529591
# Fuel_Type_Petrol          0.769312
# Seller_Type_Individual   -1.262606
# Transmission_Manual      -1.555690
# dtype: float64

# %%
print(lr.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:          Selling_Price   R-squared:                       0.883
# Model:                            OLS   Adj. R-squared:                  0.879
# Method:                 Least Squares   F-statistic:                     203.7
# Date:                Thu, 28 Apr 2022   Prob (F-statistic):           3.75e-96
# Time:                        19:08:18   Log-Likelihood:                -440.76
# No. Observations:                 225   AIC:                             899.5
# Df Residuals:                     216   BIC:                             930.3
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# const                      5.4680      1.356      4.031      0.000       2.794       8.142
# ...

# %%
mpl.scatter(y_test,y_pred)
mpl.plot(color = "red")
mpl.show()

# %%
sb.regplot(x=y_test, y=y_pred, ci=None, color="g")
# Out:
# <AxesSubplot:xlabel='Selling_Price'>

# %%
import pickle
picke_out=open("car_price.pkl","wb")
pickle.dump(y_pred,picke_out)
picke_out.close()
